# %%
import os
os.chdir(r"c:\projects\PY_MLE")

import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Okt
from tqdm import tqdm

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings.txt", filename="ratings.txt")
# Out:
# ('ratings.txt', <http.client.HTTPMessage at 0x2b8b9e11d50>)

# %%
train_data = pd.read_table('ratings.txt')
train_data[:5]
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2   4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3   9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4  10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1

# %%
train_data.isnull().values.any()
# Out:
# True

# %%
train_data = train_data.dropna(how='any')
train_data.isnull().values.any()
# Out:
# False

# %%
train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","", regex=True)
train_data[:5]
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산업...      1
# 2   4655635                   폴리스스토리 시리즈는 부터 뉴까지 버릴께 하나도 없음 최고      1
# 3   9251303   와 연기가 진짜 개쩔구나 지루할거라고 생각했는데 몰입해서 봤다 그래 이런게 진짜 영화지      1
# 4  10067386                         안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화      1

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으 로' ,'자','에','와','한','하다']

okt = Okt()
tokenized_data = []

for sentence in tqdm(train_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True)
    stopwords_removed_sentence = [word for word in tokenized_data if word not in stopwords]
    tokenized_data.append(stopwords_removed_sentence)

tokenized_data[:5]
# Out:
#  35%|███▍      | 69649/199992 [1:21:16<2:32:05, 14.28it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 6
#       3 okt = Okt()
#       4 tokenized_data = []
# ----> 6 for sentence in tqdm(train_data['document']):
#       7     tokenized_sentence = okt.morphs(sentence, stem=True)
#       8     stopwords_removed_sentence = [word for word in tokenized_data if word not in stopwords]
#
# File ~\anaconda3\Lib\site-packages\tqdm\std.py:1188, in tqdm.__iter__(self)
#    1186 dt = cur_t - last_print_t
#    1187 if dt >= mininterval and cur_t >= min_start_t:
# -> 1188     self.update(n - last_print_n)
#    1189     last_print_n = self.last_print_n
#    1190     last_print_t = self.last_print_t
#
# File ~\anaconda3\Lib\site-packages\tqdm\std.py:1239, in tqdm.update(self, n)
#    1237     self._ema_dn(dn)
#    1238     self._ema_dt(dt)
# ...

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences=tokenized_data, vector_size=100, window=5, min_count=5, workers=4, sg=0)

# %%
model.wb.vectors.shape

# %%
# 테스트
model.wv.most_similar('최민식')
