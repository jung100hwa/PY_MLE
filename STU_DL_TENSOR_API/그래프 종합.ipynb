# %% [markdown]
# 파이참에서는 쥬피터노트북은 잘 되지 않는다
# ![image.png](attachment:a7a24fe2-fc21-437f-9917-433fb5131de4.png)
#
# 1. 그림과 같이 먼저 쥬피터노트북을 브라우저에서 실행시키고 거기서 되면 서버가 실행되는 것이다.
# 2. 파이참에서 바로 할려면 잘 안됨

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.style.use('seaborn-v0_8-white')

# %% [markdown]
# 기본직선을 표시

# %%
fig = plt.figure()
ax = plt.axes()
plt.plot([0, 0.2, 0.4, 0.6, 0.8, 1] * 5)
plt.show()

# %% [markdown]
# 곡선을 표시

# %%
x = np.arange(0,10, 0.01)
fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# 라인 스타일을 지정

# %%
plt.plot(np.random.randn(50).cumsum(), linestyle='-')
plt.plot(np.random.randn(50).cumsum(), linestyle='--')
plt.plot(np.random.randn(50).cumsum(), linestyle='-.')
plt.plot(np.random.randn(50).cumsum(), linestyle=':')
plt.show()

# %% [markdown]
# 컬러스타일을 지정
# 이런게 #1234 이건 파워포인트로 정말 편한데

# %%
plt.plot(np.random.randn(50).cumsum(), color = 'g')
plt.plot(np.random.randn(50).cumsum(), color = '#156082') # 이런것도 가능
plt.plot(np.random.randn(50).cumsum(), color='b')
plt.plot(np.random.randn(50).cumsum(), color='r')
plt.show()

# %% [markdown]
# 라인과 컬러를 한번에

# %%
plt.plot(np.random.randn(50).cumsum(), 'g-')
plt.plot(np.random.randn(50).cumsum(), 'b--')
plt.plot(np.random.randn(50).cumsum(), 'r-.')
plt.plot(np.random.randn(50).cumsum(), 'y:')
plt.show()

# %% [markdown]
# 축 경계를 지정함

# %%
plt.plot(np.random.randn(50))
plt.xlim(-1, 50)
plt.ylim(-5,5)
plt.show()

# %% [markdown]
# 축 경계를 꽉차게

# %%
plt.plot(np.random.randn(50))
plt.axis('tight')
plt.title("TITLE")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# 범례 표시
# 1.위치지정. ==> 알아서 지정할려면 best

# %%
plt.plot(np.random.randn(50), 'r-', label='first')
plt.plot(np.random.randn(50), 'g--',label='second')
plt.plot(np.random.randn(50), 'b:',label='third')
plt.axis('tight')
plt.title("TITLE")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %% [markdown]
# 아래와 같이 subplots 함수를 이용해서 그릴 수도 있다.
# ax에 포함된 함수가 있고 plt에 포함된 함수가 있다.

# %%
fig, ax = plt.subplots()
ax.plot(np.random.randn(50), 'r-', label='first')
ax.plot(np.random.randn(50), 'g--',label='second')
ax.plot(np.random.randn(50), 'b:',label='third')
ax.axis('tight')
ax.legend()
plt.title("TITLE")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
# 컬러바 형태로 그리기
# 이형태는 메트릭스를 표현하기에 좋은 그림 같다.

# %%
data = np.random.rand(4,4)
print(data)
plt.imshow(data, cmap='viridis')
plt.colorbar()
plt.title("colorbar")
plt.show()

# %% [markdown]
# 다중 플랫으로 그리기

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4) # 서브플롯 여백주기
for i in range(1,10):
    plt.subplot(3,3,i)
    plt.text(0.5, 0.5, str((3,3,i)), ha='center')

# %%
fig, ax = plt.subplots(3,3,sharex='col', sharey='row')
for i in range(3):
    for j in range(3):
        ax[i,j].text(0.5,0.5,str((i,j)),ha='center', va='center') # ha, va는 글자의 어느 위치를 기분으로 0,5, 0,5 할것인가를 결정

# %%
plt.figure(figsize=(15,10))

x = range(1,21)
columns = [np.random.randn(20) * i for i in range(1,7)]
i = 0
for j in columns:
    i += 1
    plt.subplot(3,2,i)
    plt.plot(x, j, marker='o', linewidth=1, label=np.argmax(j))
    plt.xlim(-1,22)
    plt.ylim(j.min()-1, j.max()+1)
    plt.legend()

# %% [markdown]
# 어노테이션 그리기
# 그래프 중에 중요한 부분에 글자를 적는 것
# ** 중요한 지점을 계산에 의해서 나와야 되는 것 같다.

# %%
x = np.arange(1,40)
y = x

plt.scatter(x, y, marker='.')
plt.axis('equal')
plt.annotate('key point', xy = (10,10), xytext=(20,10), arrowprops=dict(shrink=0.05))
plt.grid()

# %% [markdown]
# 막대 플롯 그리기

# %%
h = [np.random.randn() * i for i in range(1,6)]
names = ['A', 'B', 'C', 'D', 'E']
y = np.arange(len(names))
plt.bar(y, h)
plt.xticks(y, names)
plt.xlabel('group')
plt.ylabel('value')
plt.grid()

# %%
h = [np.random.randn() * i for i in range(1,6)]
names = ['A', 'B', 'C', 'D', 'E']
y = np.arange(len(names))
plt.barh(y, h)
plt.yticks(y, names)
plt.ylabel('group')
plt.xlabel('value')
plt.grid()

# %%
bar_width = 0.25

bars1 = [14,17,9, 8, 7]
bars2 = [12,14,6, 2, 6]
bars3 = [11,15,9, 3, 3]

r1 = np.arange(len(bars1))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

plt.bar(r1, bars1, color='royalblue', width=bar_width)
plt.bar(r2, bars2, color='skyblue', width=bar_width)
plt.bar(r3, bars3, color='lightblue', width=bar_width)

# %% [markdown]
# 박스플롯. 데이터의 분포도를 알수 있는 아주 유용한 도구

# %%
r1 = np.random.normal(loc=0, scale=0.5, size=100)
r2 = np.random.normal(loc=0, scale=1.0, size=100)

f, ax = plt.subplots(1,1)
ax.boxplot((r1,r2))
ax.set_xticklabels(['r1','r2'])
plt.show()
print(r1)
print(r2)

# %% [markdown]
# 스캐터

# %%
x = np.linspace(0,10,100)
y = np.cos(x)

plt.scatter(x, y, marker ='o')
plt.show()

# %% [markdown]
# 스캐터를 통해 버블 차트 표시

# %%
x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)
sizes = 1000 * np.random.rand(100)

plt.scatter(x,y, c=colors, s=sizes, alpha=0.5, cmap='viridis')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# 일관성 그래프(주식 등에 활용)
# 두개의 그래프가 있는데 차이가 일정하게 유지되는지 아닌지를 파악

# %%
## Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 ## white noise 1
nse2 = np.random.randn(len(t))                 ## white noise 2

s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

fig, axs = plt.subplots(2, 1)
axs[0].plot(t, s1, t, s2)
axs[0].set_xlim(0, 2)
axs[0].set_xlabel('Time')
axs[0].set_ylabel('s1 and s2')
axs[0].grid(True)

cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
axs[1].set_ylabel('Coherence')

fig.tight_layout()
plt.show()

# %% [markdown]
# 히스토그램
# 이것은 바와 비슷하지만 역할이 다름. 바는 바마다 값이 있지만 히스토그램은 구간정의해서 구간에 포함된 개수를 표시

# %%
data = np.random.randn(10000)
# data = np.array([1,2,3,4,4,4,4,4,4,4,5,6,7,7,7,8])
plt.hist(data, bins=20)

# %% [markdown]
# 파이차트. 사실 딥러닝에서는 사용할 일이 없을 것 같다.

# %%
data = [10,30,50,80,19]
ca = ['A','B','C','D','E']

plt.pie(data, labels=ca, autopct='%0.1f%%')
plt.legend()
plt.grid()
